# %%
import numpy as np
import pandas as pd

# %%
file_path = "/home/sunag/scFoundation/DeepCDR/data/50M-0.1B-res_embedding.npy"

X = np.load(file_path)
X_new = X[:4, :].copy()

file_path = '/home/sunag/scFoundation/DeepCDR/data/custom_embedding.npy'

np.save(file_path, X_new)

print(f"Array successfully saved to {file_path}")
# Out:
# Array successfully saved to /home/sunag/scFoundation/DeepCDR/data/custom_embeddings.npy

# %%
x = pd.read_csv("")
